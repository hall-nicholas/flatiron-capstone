# %%
import numpy as np
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
import cv2
import os
import glob

import functions as fn

# %%
dataDir='../data'
trainDir='train2017'
valDir='val2017'
seed=42
transformed=.5
train=.8
test = 1 - train
strategy_list = ['left', 'right']
destDataDir='../created_data'
destTrainDir='train'
destTestDir='test'
destValDir='val'
destNormDir='NORMAL'
destRSDir='ROLLING_SHUTTER'

np.random.seed(seed)

trainAnn=f'{dataDir}/annotations/instances_{trainDir}.json'
valAnn=f'{dataDir}/annotations/instances_{valDir}.json'

cocoTrain=COCO(trainAnn)
cocoVal=COCO(valAnn)

catIdsTrain = cocoTrain.getCatIds(catNms=['person'])
imgIdsTrain = cocoTrain.getImgIds(catIds=catIdsTrain)
imgIdsTrain = cocoTrain.getImgIds(imgIds=imgIdsTrain)
annIdsTrain = cocoTrain.getAnnIds(imgIds=imgIdsTrain, catIds=catIdsTrain, iscrowd=None)

catIdsVal = cocoVal.getCatIds(catNms=['person'])
imgIdsVal = cocoVal.getImgIds(catIds=catIdsVal)
imgIdsVal = cocoVal.getImgIds(imgIds=imgIdsVal)
annIdsVal = cocoVal.getAnnIds(imgIds=imgIdsVal, catIds=catIdsVal, iscrowd=None)
# Out:
# loading annotations into memory...
# Done (t=9.70s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.34s)
# creating index...
# index created!

# %%
count = 0
limit = 10

# 69 as control
# 42 works
# 7 works


idx = 42

testImg = cocoTrain.loadImgs(imgIdsTrain[idx])[0]
testAnn = cocoTrain.loadAnns(cocoTrain.getAnnIds(imgIds=testImg['id'], catIds=catIdsTrain, iscrowd=None))

fpath = '{}/{}/{}'.format(dataDir, trainDir, testImg['file_name'])

testImgArr = cv2.imread(fpath)

fn.remove_true_blacks(testImgArr)

whichAnn = np.random.randint(0, len(testAnn))

testSpecAnn = testAnn[whichAnn] # np.random.randint(0, len(testAnn))
strategy = strategy_list[np.random.randint(0, len(strategy_list))]

strategy='left'

print(whichAnn, strategy)

maskedTest, maskedTestInv = fn.generate_masked_images(testImgArr, testSpecAnn)

newMaskedTest = fn.apply_rolling_shutter(maskedTest, testSpecAnn, strategy=strategy)

newMaskedTestInv = fn.fill_inv_masked(maskedTestInv, testSpecAnn, strategy=strategy)

final_output = fn.recombine_masked_imgs(newMaskedTest, newMaskedTestInv)

fn.display_image(final_output)
# Out:
# 0 left

# %%
#cv2.imwrite('modified.png', final_output)
#cv2.imwrite('original.png', testImgArr)

# %%
type(imgIdsTrain[idx])
# Out:
# int

# %%
for i in range(10):
    if i == 7:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9

# %%
np.random.seed(seed)

prog = 0
iters = 0
limit = 5000 # number of images to process for both RS and normal; results in double the amount (limit of 200 = 400 total images)

ids_ignore = []

destDir = os.path.join(os.getcwd(), destDataDir.replace('/', '\\'))
for traintestval in [destTrainDir, destTestDir, destValDir]:
    for normrs in [destNormDir, destRSDir]:
        files = glob.glob(f'{destDir}\\{traintestval}\\{normrs}\\*')
        for f in files:
            os.remove(f)

### ROLLING SHUTTER

ids_list = []
for i in np.arange(limit):
    id = np.random.choice(imgIdsTrain)
    if int(id) not in ids_ignore:
        ids_list.append(id)

for id in ids_list: # rolling shutter
    print(f'Loading image id: {id}')

    try:
        imgDict = cocoTrain.loadImgs([id])[0]
        annDict = cocoTrain.loadAnns(cocoTrain.getAnnIds(imgIds=imgDict['id'], catIds=catIdsTrain, iscrowd=None))

        fpath = '{}/{}/{}'.format(dataDir, trainDir, imgDict['file_name'])
        img = cv2.imread(fpath)
        fn.remove_true_blacks(img)

        ann = annDict[np.random.randint(0, len(annDict))]
        strategy = strategy_list[np.random.randint(0, len(strategy_list))]

        masked, maskedInv = fn.generate_masked_images(img, ann)

        masked_rs = fn.apply_rolling_shutter(masked, ann, intensity=.7, strategy=strategy)

        maskedInv_filled = fn.fill_inv_masked(maskedInv, ann, strategy=strategy)

        final = fn.recombine_masked_imgs(masked_rs, maskedInv_filled)

        if(prog < train):
            fpath = '{}/{}/{}/{}'.format(destDataDir, destTrainDir, destRSDir, f'rs-{iters}.png')
            cv2.imwrite(fpath, final)
        #elif(prog < train + val):
        #    fpath = '{}/{}/{}/{}'.format(destDataDir, destValDir, destRSDir, f'rs-{iters}.png')
        #    cv2.imwrite(fpath, final)
        else:
            fpath = '{}/{}/{}/{}'.format(destDataDir, destTestDir, destRSDir, f'rs-{iters}.png')
            cv2.imwrite(fpath, final)
    except:
        print('Something went wrong, continuing to next image')

    prog += 1 / len(ids_list)
    iters += 1
    print(f'Finished! {50*prog:.2f}% done')

### NORMAL

prog = 0
iters = 0
ids_list = []
for i in np.arange(limit):
    ids_list.append(np.random.choice(imgIdsTrain))

for id in ids_list: 
    print(f'Loading image id: {id}')

    imgDict = cocoTrain.loadImgs([id])[0]
    annDict = cocoTrain.loadAnns(cocoTrain.getAnnIds(imgIds=imgDict['id'], catIds=catIdsTrain, iscrowd=None))

    fpath = '{}/{}/{}'.format(dataDir, trainDir, imgDict['file_name'])
    img = cv2.imread(fpath)
    fn.remove_true_blacks(img)

    if(prog < train):
        fpath = '{}/{}/{}/{}'.format(destDataDir, destTrainDir, destNormDir, f'rs-{iters}.png')
        cv2.imwrite(fpath, img)
    #elif(prog < train + val):
    #    fpath = '{}/{}/{}/{}'.format(destDataDir, destValDir, destNormDir, f'rs-{iters}.png')
    #    cv2.imwrite(fpath, img)
    else:
        fpath = '{}/{}/{}/{}'.format(destDataDir, destTestDir, destNormDir, f'rs-{iters}.png')
        cv2.imwrite(fpath, img)

    prog += 1 / len(ids_list)
    iters += 1
    print(f'Finished loading! {50 + 50*prog:.2f}% done')
# Out:
# Loading image id: 375637
# Finished! 0.01% done
# Loading image id: 290899
# Finished! 0.02% done
# Loading image id: 263700
# Finished! 0.03% done
# Loading image id: 72024
# Finished! 0.04% done
# Loading image id: 389649
# Finished! 0.05% done
# Loading image id: 239558
# Finished! 0.06% done
# Loading image id: 217936
# Finished! 0.07% done
# Loading image id: 544933
# Finished! 0.08% done
# Loading image id: 371910
# Finished! 0.09% done
# Loading image id: 535820
# Finished! 0.10% done
# Loading image id: 161673
# Finished! 0.11% done
# Loading image id: 575305
# Finished loading! 97.43% done
# Loading image id: 233351
# Finished loading! 97.44% done
# Loading image id: 286912
# Finished loading! 97.45% done
# Loading image id: 100827
# Finished loading! 97.46% done
# Loading image id: 413852
# Finished loading! 97.47% done
# Loading image id: 220872
# Finished loading! 97.48% done
# Loading image id: 233116
# Finished loading! 97.49% done
# Loading image id: 114352
# Finished loading! 97.50% done
# Loading image id: 373199
# Finished loading! 97.51% done
# Loading image id: 439658
# Finished loading! 97.52% done
# Loading image id: 108056
# Finished loading! 97.53% done
# Loading image id: 239693
# Finished loading! 97.54% done
# Loading image id: 439179
# Finished loading! 97.55% done
# Loading image id: 196490
# Finished loading! 97.56% done
# Loading image id: 564489
# Finished loading! 97.57% done
# Loading image id: 114744
# Finished loading! 97.58% done
# Loading image id: 60419
# Finished loading! 97.59% done
# Loading image id: 436522
# Finished loading! 97.60% done
# Loading image id: 410966
# Finished loading! 97.61% done
# Loading image id: 203655
# Finished loading! 97.62% done
# Loading image id: 520554
# Finished loading! 97.63% done
# Loading image id: 494471
# Finished loading! 97.64% done
# Loading image id: 447941
# Finished loading! 97.65% done
# Loading image id: 288478
# Finished loading! 97.66% done
# Loading image id: 401482
# Finished loading! 97.67% done
# Loading image id: 196170
# Finished loading! 97.68% done
# Loading image id: 183015
# Finished loading! 97.69% done
# Loading image id: 366795
# Finished loading! 97.70% done
# Loading image id: 491981
# Finished loading! 97.71% done
# Loading image id: 548361
# Finished loading! 97.72% done
# Loading image id: 263176
# Finished loading! 97.73% done
# Loading image id: 123995
# Finished loading! 97.74% done
# Loading image id: 397349
# Finished loading! 97.75% done
# Loading image id: 265938
# Finished loading! 97.76% done
# Loading image id: 28961
# Finished loading! 97.77% done
# Loading image id: 429039
# Finished loading! 97.78% done
# Loading image id: 558234
# Finished loading! 97.79% done
# Loading image id: 163840
# Finished loading! 97.80% done
# Loading image id: 517941
# Finished loading! 97.81% done
# Loading image id: 269360
# Finished loading! 97.82% done
# Loading image id: 145793
# Finished loading! 97.83% done
# Loading image id: 399582
# Finished loading! 97.84% done
# Loading image id: 121393
# Finished loading! 97.85% done
# Loading image id: 355668
# Finished loading! 97.86% done
# Loading image id: 30395
# Finished loading! 97.87% done
# Loading image id: 207640
# Finished loading! 97.88% done
# Loading image id: 579101
# Finished loading! 97.89% done
# Loading image id: 35374
# Finished loading! 97.90% done
# Loading image id: 495199
# Finished loading! 97.91% done
# Loading image id: 531949
# Finished loading! 97.92% done
# Loading image id: 281625
# Finished loading! 97.93% done
# Loading image id: 301158
# Finished loading! 97.94% done
# Loading image id: 485649
# Finished loading! 97.95% done
# Loading image id: 93579
# Finished loading! 97.96% done
# Loading image id: 488974
# Finished loading! 97.97% done
# Loading image id: 436406
# Finished loading! 97.98% done
# Loading image id: 165883
# Finished loading! 97.99% done
# Loading image id: 561655
# Finished loading! 98.00% done
# Loading image id: 260101
# Finished loading! 98.01% done
# Loading image id: 504917
# Finished loading! 98.02% done
# Loading image id: 249455
# Finished loading! 98.03% done
# Loading image id: 279444
# Finished loading! 98.04% done
# Loading image id: 229000
# Finished loading! 98.05% done
# Loading image id: 517938
# Finished loading! 98.06% done
# Loading image id: 85847
# Finished loading! 98.07% done
# Loading image id: 231240
# Finished loading! 98.08% done
# Loading image id: 431893
# Finished loading! 98.09% done
# Loading image id: 8445
# Finished loading! 98.10% done
# Loading image id: 201042
# Finished loading! 98.11% done
# Loading image id: 317825
# Finished loading! 98.12% done
# Loading image id: 359727
# Finished loading! 98.13% done
# Loading image id: 213405
# Finished loading! 98.14% done
# Loading image id: 331250
# Finished loading! 98.15% done
# Loading image id: 453586
# Finished loading! 98.16% done
# Loading image id: 533550
# Finished loading! 98.17% done
# Loading image id: 519264
# Finished loading! 98.18% done
# Loading image id: 9203
# Finished loading! 98.19% done
# Loading image id: 538478
# Finished loading! 98.20% done
# Loading image id: 381093
# Finished loading! 98.21% done
# Loading image id: 246970
# Finished loading! 98.22% done
# Loading image id: 57461
# Finished loading! 98.23% done
# Loading image id: 282692
# Finished loading! 98.24% done
# Loading image id: 327702
# Finished loading! 98.25% done
# Loading image id: 242426
# Finished loading! 98.26% done
# Loading image id: 548834
# Finished loading! 98.27% done
# Loading image id: 356002
# Finished loading! 98.28% done
# Loading image id: 246855
# Finished loading! 98.29% done
# Loading image id: 479334
# Finished loading! 98.30% done
# Loading image id: 23019
# Finished loading! 98.31% done
# Loading image id: 4441
# Finished loading! 98.32% done
# Loading image id: 479350
# Finished loading! 98.33% done
# Loading image id: 451154
# Finished loading! 98.34% done
# Loading image id: 525249
# Finished loading! 98.35% done
# Loading image id: 476802
# Finished loading! 98.36% done
# Loading image id: 185850
# Finished loading! 98.37% done
# Loading image id: 201375
# Finished loading! 98.38% done
# Loading image id: 32809
# Finished loading! 98.39% done
# Loading image id: 298034
# Finished loading! 98.40% done
# Loading image id: 195978
# Finished loading! 98.41% done
# Loading image id: 25467
# Finished loading! 98.42% done
# Loading image id: 486413
# Finished loading! 98.43% done
# Loading image id: 243017
# Finished loading! 98.44% done
# Loading image id: 289901
# Finished loading! 98.45% done
# Loading image id: 533283
# Finished loading! 98.46% done
# Loading image id: 357109
# Finished loading! 98.47% done
# Loading image id: 356490
# Finished loading! 98.48% done
# Loading image id: 278395
# Finished loading! 98.49% done
# Loading image id: 576598
# Finished loading! 98.50% done
# Loading image id: 211420
# Finished loading! 98.51% done
# Loading image id: 535218
# Finished loading! 98.52% done
# Loading image id: 133619
# Finished loading! 98.53% done
# Loading image id: 202489
# Finished loading! 98.54% done
# Loading image id: 39768
# Finished loading! 98.55% done
# Loading image id: 354309
# Finished loading! 98.56% done
# Loading image id: 409216
# Finished loading! 98.57% done
# Loading image id: 510663
# Finished loading! 98.58% done
# Loading image id: 40144
# Finished loading! 98.59% done
# Loading image id: 443547
# Finished loading! 98.60% done
# Loading image id: 531532
# Finished loading! 98.61% done
# Loading image id: 539830
# Finished loading! 98.62% done
# Loading image id: 246183
# Finished loading! 98.63% done
# Loading image id: 424867
# Finished loading! 98.64% done
# Loading image id: 123944
# Finished loading! 98.65% done
# Loading image id: 564934
# Finished loading! 98.66% done
# Loading image id: 324650
# Finished loading! 98.67% done
# Loading image id: 571051
# Finished loading! 98.68% done
# Loading image id: 472729
# Finished loading! 98.69% done
# Loading image id: 244209
# Finished loading! 98.70% done
# Loading image id: 411108
# Finished loading! 98.71% done
# Loading image id: 561658
# Finished loading! 98.72% done
# Loading image id: 11788
# Finished loading! 98.73% done
# Loading image id: 366500
# Finished loading! 98.74% done
# Loading image id: 549845
# Finished loading! 98.75% done
# Loading image id: 418354
# Finished loading! 98.76% done
# Loading image id: 105951
# Finished loading! 98.77% done
# Loading image id: 387558
# Finished loading! 98.78% done
# Loading image id: 517232
# Finished loading! 98.79% done
# Loading image id: 48863
# Finished loading! 98.80% done
# Loading image id: 445327
# Finished loading! 98.81% done
# Loading image id: 294550
# Finished loading! 98.82% done
# Loading image id: 330050
# Finished loading! 98.83% done
# Loading image id: 475813
# Finished loading! 98.84% done
# Loading image id: 182334
# Finished loading! 98.85% done
# Loading image id: 30094
# Finished loading! 98.86% done
# Loading image id: 448211
# Finished loading! 98.87% done
# Loading image id: 563053
# Finished loading! 98.88% done
# Loading image id: 45016
# Finished loading! 98.89% done
# Loading image id: 276893
# Finished loading! 98.90% done
# Loading image id: 564058
# Finished loading! 98.91% done
# Loading image id: 137042
# Finished loading! 98.92% done
# Loading image id: 46674
# Finished loading! 98.93% done
# Loading image id: 328427
# Finished loading! 98.94% done
# Loading image id: 57526
# Finished loading! 98.95% done
# Loading image id: 143499
# Finished loading! 98.96% done
# Loading image id: 233471
# Finished loading! 98.97% done
# Loading image id: 566321
# Finished loading! 98.98% done
# Loading image id: 544065
# Finished loading! 98.99% done
# Loading image id: 280805
# Finished loading! 99.00% done
# Loading image id: 442321
# Finished loading! 99.01% done
# Loading image id: 510161
# Finished loading! 99.02% done
# Loading image id: 80821
# Finished loading! 99.03% done
# Loading image id: 332271
# Finished loading! 99.04% done
# Loading image id: 565395
# Finished loading! 99.05% done
# Loading image id: 69432
# Finished loading! 99.06% done
# Loading image id: 121875
# Finished loading! 99.07% done
# Loading image id: 457861
# Finished loading! 99.08% done
# Loading image id: 549518
# Finished loading! 99.09% done
# Loading image id: 315165
# Finished loading! 99.10% done
# Loading image id: 99392
# Finished loading! 99.11% done
# Loading image id: 131174
# Finished loading! 99.12% done
# Loading image id: 511623
# Finished loading! 99.13% done
# Loading image id: 88183
# Finished loading! 99.14% done
# Loading image id: 322160
# Finished loading! 99.15% done
# Loading image id: 338054
# Finished loading! 99.16% done
# Loading image id: 146773
# Finished loading! 99.17% done
# Loading image id: 178438
# Finished loading! 99.18% done
# Loading image id: 303413
# Finished loading! 99.19% done
# Loading image id: 263275
# Finished loading! 99.20% done
# Loading image id: 539087
# Finished loading! 99.21% done
# Loading image id: 575428
# Finished loading! 99.22% done
# Loading image id: 85787
# Finished loading! 99.23% done
# Loading image id: 73293
# Finished loading! 99.24% done
# Loading image id: 478781
# Finished loading! 99.25% done
# Loading image id: 81885
# Finished loading! 99.26% done
# Loading image id: 412752
# Finished loading! 99.27% done
# Loading image id: 274949
# Finished loading! 99.28% done
# Loading image id: 574343
# Finished loading! 99.29% done
# Loading image id: 45920
# Finished loading! 99.30% done
# Loading image id: 71021
# Finished loading! 99.31% done
# Loading image id: 240951
# Finished loading! 99.32% done
# Loading image id: 574037
# Finished loading! 99.33% done
# Loading image id: 450110
# Finished loading! 99.34% done
# Loading image id: 1720
# Finished loading! 99.35% done
# Loading image id: 182634
# Finished loading! 99.36% done
# Loading image id: 409841
# Finished loading! 99.37% done
# Loading image id: 75630
# Finished loading! 99.38% done
# Loading image id: 557245
# Finished loading! 99.39% done
# Loading image id: 546864
# Finished loading! 99.40% done
# Loading image id: 384289
# Finished loading! 99.41% done
# Loading image id: 321432
# Finished loading! 99.42% done
# Loading image id: 335013
# Finished loading! 99.43% done
# Loading image id: 542090
# Finished loading! 99.44% done
# Loading image id: 12669
# Finished loading! 99.45% done
# Loading image id: 118110
# Finished loading! 99.46% done
# Loading image id: 313129
# Finished loading! 99.47% done
# Loading image id: 45392
# Finished loading! 99.48% done
# Loading image id: 297227
# Finished loading! 99.49% done
# Loading image id: 492466
# Finished loading! 99.50% done
# Loading image id: 66319
# Finished loading! 99.51% done
# Loading image id: 296629
# Finished loading! 99.52% done
# Loading image id: 404351
# Finished loading! 99.53% done
# Loading image id: 467081
# Finished loading! 99.54% done
# Loading image id: 445309
# Finished loading! 99.55% done
# Loading image id: 291854
# Finished loading! 99.56% done
# Loading image id: 461429
# Finished loading! 99.57% done
# Loading image id: 174842
# Finished loading! 99.58% done
# Loading image id: 270024
# Finished loading! 99.59% done
# Loading image id: 476269
# Finished loading! 99.60% done
# Loading image id: 134643
# Finished loading! 99.61% done
# Loading image id: 55747
# Finished loading! 99.62% done
# Loading image id: 55202
# Finished loading! 99.63% done
# Loading image id: 65415
# Finished loading! 99.64% done
# Loading image id: 542925
# Finished loading! 99.65% done
# Loading image id: 261346
# Finished loading! 99.66% done
# Loading image id: 340047
# Finished loading! 99.67% done
# Loading image id: 312390
# Finished loading! 99.68% done
# Loading image id: 398817
# Finished loading! 99.69% done
# Loading image id: 71667
# Finished loading! 99.70% done
# Loading image id: 3786
# Finished loading! 99.71% done
# Loading image id: 406766
# Finished loading! 99.72% done
# Loading image id: 23874
# Finished loading! 99.73% done
# Loading image id: 48047
# Finished loading! 99.74% done
# Loading image id: 360870
# Finished loading! 99.75% done
# Loading image id: 524375
# Finished loading! 99.76% done
# Loading image id: 200288
# Finished loading! 99.77% done
# Loading image id: 361594
# Finished loading! 99.78% done
# Loading image id: 240915
# Finished loading! 99.79% done
# Loading image id: 355571
# Finished loading! 99.80% done
# Loading image id: 29161
# Finished loading! 99.81% done
# Loading image id: 321390
# Finished loading! 99.82% done
# Loading image id: 276621
# Finished loading! 99.83% done
# Loading image id: 50106
# Finished loading! 99.84% done
# Loading image id: 359149
# Finished loading! 99.85% done
# Loading image id: 94558
# Finished loading! 99.86% done
# Loading image id: 174773
# Finished loading! 99.87% done
# Loading image id: 208517
# Finished loading! 99.88% done
# Loading image id: 240199
# Finished loading! 99.89% done
# Loading image id: 246797
# Finished loading! 99.90% done
# Loading image id: 170925
# Finished loading! 99.91% done
# Loading image id: 109848
# Finished loading! 99.92% done
# Loading image id: 295162
# Finished loading! 99.93% done
# Loading image id: 351973
# Finished loading! 99.94% done
# Loading image id: 76293
# Finished loading! 99.95% done
# Loading image id: 135288
# Finished loading! 99.96% done
# Loading image id: 572172
# Finished loading! 99.97% done
# Loading image id: 307873
# Finished loading! 99.98% done
# Loading image id: 513123
# Finished loading! 99.99% done
# Loading image id: 213034
# Finished loading! 100.00% done

# %%
""" np.random.seed(seed)

prog = 0
iters = 0
limit =  # number of images to process for both RS and normal; results in double the amount (limit of 200 = 400 total images)

ids_ignore = [126798, 44140, 502360, 42779, 506987]

destDir = os.path.join(os.getcwd(), destDataDir.replace('/', '\\'))
for traintestval in [destTrainDir, destTestDir, destValDir]:
    for normrs in [destNormDir, destRSDir]:
        files = glob.glob(f'{destDir}\\{traintestval}\\{normrs}\\*')
        for f in files:
            os.remove(f)

### ROLLING SHUTTER

ids_list = []
for i in np.arange(limit):
    id = np.random.choice(imgIdsTrain)
    if int(id) not in ids_ignore:
        ids_list.append(id)

for id in ids_list: # rolling shutter
    print(f'Loading image id: {id}')

    imgDict = cocoTrain.loadImgs([id])[0]
    annDict = cocoTrain.loadAnns(cocoTrain.getAnnIds(imgIds=imgDict['id'], catIds=catIdsTrain, iscrowd=None))

    fpath = '{}/{}/{}'.format(dataDir, trainDir, imgDict['file_name'])
    img = cv2.imread(fpath)
    fn.remove_true_blacks(img)

    ann = annDict[np.random.randint(0, len(annDict))]
    strategy = strategy_list[np.random.randint(0, len(strategy_list))]

    masked, maskedInv = fn.generate_masked_images(img, ann)

    masked_rs = fn.apply_rolling_shutter(masked, ann, strategy=strategy)

    maskedInv_filled = fn.fill_inv_masked(maskedInv, ann, strategy=strategy)

    final = fn.recombine_masked_imgs(masked_rs, maskedInv_filled)

    if(prog < train):
        fpath = '{}/{}/{}/{}'.format(destDataDir, destTrainDir, destRSDir, f'rs-{iters}.png')
        cv2.imwrite(fpath, final)
    #elif(prog < train + val):
    #    fpath = '{}/{}/{}/{}'.format(destDataDir, destValDir, destRSDir, f'rs-{iters}.png')
    #    cv2.imwrite(fpath, final)
    else:
        fpath = '{}/{}/{}/{}'.format(destDataDir, destTestDir, destRSDir, f'rs-{iters}.png')
        cv2.imwrite(fpath, final)

    prog += 1 / len(ids_list)
    iters += 1
    print(f'Finished loading! {50*prog:.2f}% done')

### NORMAL

prog = 0
iters = 0
ids_list = []
for i in np.arange(limit):
    ids_list.append(np.random.choice(imgIdsTrain))

for id in ids_list: 
    print(f'Loading image id: {id}')

    imgDict = cocoTrain.loadImgs([id])[0]
    annDict = cocoTrain.loadAnns(cocoTrain.getAnnIds(imgIds=imgDict['id'], catIds=catIdsTrain, iscrowd=None))

    fpath = '{}/{}/{}'.format(dataDir, trainDir, imgDict['file_name'])
    img = cv2.imread(fpath)
    fn.remove_true_blacks(img)

    if(prog < train):
        fpath = '{}/{}/{}/{}'.format(destDataDir, destTrainDir, destNormDir, f'rs-{iters}.png')
        cv2.imwrite(fpath, img)
    #elif(prog < train + val):
    #    fpath = '{}/{}/{}/{}'.format(destDataDir, destValDir, destNormDir, f'rs-{iters}.png')
    #    cv2.imwrite(fpath, img)
    else:
        fpath = '{}/{}/{}/{}'.format(destDataDir, destTestDir, destNormDir, f'rs-{iters}.png')
        cv2.imwrite(fpath, img)

    prog += 1 / len(ids_list)
    iters += 1
    print(f'Finished loading! {50 + 50*prog:.2f}% done')
 """
# Out:
# Loading image id: 441213
# Finished loading! 2.38% done
# Loading image id: 375637
# Finished loading! 4.76% done
# Loading image id: 290899
# Finished loading! 7.14% done
# Loading image id: 263700
# Finished loading! 9.52% done
# Loading image id: 72024
# Finished loading! 11.90% done
# Loading image id: 389649
# Finished loading! 14.29% done
# Loading image id: 239558
# Finished loading! 16.67% done
# Loading image id: 217936
# Finished loading! 19.05% done
# Loading image id: 544933
# Finished loading! 21.43% done
# Loading image id: 371910
# Finished loading! 23.81% done
# Loading image id: 535820
# Finished loading! 26.19% done
# Loading image id: 161673
# Finished loading! 28.57% done
# Loading image id: 520978
# Finished loading! 30.95% done
# Loading image id: 331844
# Finished loading! 33.33% done
# Loading image id: 433007
# Finished loading! 35.71% done
# Loading image id: 354699
# Finished loading! 38.10% done
# Loading image id: 254577
# Finished loading! 40.48% done
# Loading image id: 347570
# Finished loading! 42.86% done
# Loading image id: 384422
# Finished loading! 45.24% done
# Loading image id: 553436
# Finished loading! 47.62% done
# Loading image id: 209531
# Finished loading! 50.00% done
# Loading image id: 540384
# Finished loading! 52.50% done
# Loading image id: 83690
# Finished loading! 55.00% done
# Loading image id: 345136
# Finished loading! 57.50% done
# Loading image id: 539754
# Finished loading! 60.00% done
# Loading image id: 82945
# Finished loading! 62.50% done
# Loading image id: 151250
# Finished loading! 65.00% done
# Loading image id: 567652
# Finished loading! 67.50% done
# Loading image id: 398126
# Finished loading! 70.00% done
# Loading image id: 112922
# Finished loading! 72.50% done
# Loading image id: 511972
# Finished loading! 75.00% done
# Loading image id: 373120
# Finished loading! 77.50% done
# Loading image id: 371330
# Finished loading! 80.00% done
# Loading image id: 42584
# Finished loading! 82.50% done
# Loading image id: 119021
# Finished loading! 85.00% done
# Loading image id: 226562
# Finished loading! 87.50% done
# Loading image id: 252535
# Finished loading! 90.00% done
# Loading image id: 555457
# Finished loading! 92.50% done
# Loading image id: 218482
# Finished loading! 95.00% done
# Loading image id: 78225
# Finished loading! 97.50% done
# Loading image id: 550824
# Finished loading! 100.00% done

# %%
print(375637 in imgIdsTrain)
# Out:
# True

# %%
cocoTrain.loadImgs([375637])
# Out:
# [{'license': 1,
#   'file_name': '000000375637.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000375637.jpg',
#   'height': 456,
#   'width': 640,
#   'date_captured': '2013-11-19 02:10:13',
#   'flickr_url': 'http://farm8.staticflickr.com/7311/8927750208_b552aa760e_z.jpg',
#   'id': 375637}]
